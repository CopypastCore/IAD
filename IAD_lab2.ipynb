# %% [markdown]
# <a href="https://colab.research.google.com/github/CopypastCore/IAD/blob/main/IAD_lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_selection import SelectKBest, f_classif
from sklearn.metrics import (
    accuracy_score,
    balanced_accuracy_score,
    f1_score,
    classification_report,
    confusion_matrix
)

import tensorflow as tf
from tensorflow.keras import layers, models

# %%
dataset = pd.read_csv('https://github.com/CopypastCore/IAD/blob/main/V8_classification_lr3.csv')
df = dataset
print(df.head())
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# /tmp/ipython-input-3989047675.py in <cell line: 0>()
# ----> 1 dataset = pd.read_csv('https://github.com/CopypastCore/IAD/blob/main/V8_classification_lr3.csv')
#       2 df = dataset
#       3 print(df.head())
#
# ...
